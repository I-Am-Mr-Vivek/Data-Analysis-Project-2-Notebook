# %% [markdown]
# # Project 2 Of Data Analysts

# %% [markdown]
# Using Python and its library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('E:\Dataset.xlsx')

# %%
df
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot        33
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat        87
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip        58
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip        82
# 4   2020-01-13   East       Boston   Cookies       Arrowroot        38
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot        34
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip       245
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat        30
# 242 2021-12-27   West  Los Angeles      Bars            Bran        30
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin        44
#
#      UnitPrice  TotalPrice
# 0         1.77       58.41
# 1         3.49      303.63
# 2         1.87      108.46
# ...

# %%
df.head(10)
# Out:
#    OrderDate Region         City  Category         Product  Quantity  \
# 0 2020-01-01   East       Boston      Bars          Carrot        33
# 1 2020-01-04   East       Boston  Crackers     Whole Wheat        87
# 2 2020-01-07   West  Los Angeles   Cookies  Chocolate Chip        58
# 3 2020-01-10   East     New York   Cookies  Chocolate Chip        82
# 4 2020-01-13   East       Boston   Cookies       Arrowroot        38
# 5 2020-01-16   East       Boston      Bars          Carrot        54
# 6 2020-01-19   East       Boston  Crackers     Whole Wheat       149
# 7 2020-01-22   West  Los Angeles      Bars          Carrot        51
# 8 2020-01-25   East     New York      Bars          Carrot       100
# 9 2020-01-28   East     New York    Snacks    Potato Chips        28
#
#    UnitPrice  TotalPrice
# 0       1.77       58.41
# 1       3.49      303.63
# 2       1.87      108.46
# 3       1.87      153.34
# 4       2.18       82.84
# 5       1.77       95.58
# ...

# %%
df.tail(10)
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 234 2021-12-03   West  Los Angeles      Bars            Bran        42
# 235 2021-12-06   West  Los Angeles   Cookies  Oatmeal Raisin       100
# 236 2021-12-09   East     New York      Bars          Carrot        38
# 237 2021-12-12   East     New York  Crackers     Whole Wheat        25
# 238 2021-12-15   West    San Diego   Cookies  Chocolate Chip        96
# 239 2021-12-18   East       Boston   Cookies       Arrowroot        34
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip       245
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat        30
# 242 2021-12-27   West  Los Angeles      Bars            Bran        30
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin        44
#
#      UnitPrice  TotalPrice
# 234       1.87       78.54
# 235       2.84      284.00
# 236       1.77       67.26
# 237       3.49       87.25
# 238       1.87      179.52
# ...

# %%
print(df.to_string())
# Out:
#      OrderDate Region         City  Category         Product  Quantity  UnitPrice  TotalPrice
# 0   2020-01-01   East       Boston      Bars          Carrot        33       1.77       58.41
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat        87       3.49      303.63
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip        58       1.87      108.46
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip        82       1.87      153.34
# 4   2020-01-13   East       Boston   Cookies       Arrowroot        38       2.18       82.84
# 5   2020-01-16   East       Boston      Bars          Carrot        54       1.77       95.58
# 6   2020-01-19   East       Boston  Crackers     Whole Wheat       149       3.49      520.01
# 7   2020-01-22   West  Los Angeles      Bars          Carrot        51       1.77       90.27
# 8   2020-01-25   East     New York      Bars          Carrot       100       1.77      177.00
# ...

# %%
df.dropna()
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot        33
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat        87
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip        58
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip        82
# 4   2020-01-13   East       Boston   Cookies       Arrowroot        38
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot        34
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip       245
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat        30
# 242 2021-12-27   West  Los Angeles      Bars            Bran        30
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin        44
#
#      UnitPrice  TotalPrice
# 0         1.77       58.41
# 1         3.49      303.63
# 2         1.87      108.46
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   244 non-null    datetime64[ns]
#  1   Region      244 non-null    object
#  2   City        244 non-null    object
#  3   Category    244 non-null    object
#  4   Product     244 non-null    object
#  5   Quantity    244 non-null    int64
#  6   UnitPrice   244 non-null    float64
#  7   TotalPrice  244 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 15.4+ KB

# %%
df.describe()
# Out:
#          Quantity   UnitPrice  TotalPrice
# count  244.000000  244.000000  244.000000
# mean    63.286885    2.200820  136.580246
# std     47.112505    0.600169  108.354231
# min     20.000000    1.350000   33.600000
# 25%     31.000000    1.770000   72.570000
# 50%     47.000000    1.870000  102.755000
# 75%     80.000000    2.840000  159.300000
# max    306.000000    3.490000  817.920000

# %%
df.dropna(subset=["Region"],inplace = True)

# %%
df
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot        33
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat        87
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip        58
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip        82
# 4   2020-01-13   East       Boston   Cookies       Arrowroot        38
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot        34
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip       245
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat        30
# 242 2021-12-27   West  Los Angeles      Bars            Bran        30
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin        44
#
#      UnitPrice  TotalPrice
# 0         1.77       58.41
# 1         3.49      303.63
# 2         1.87      108.46
# ...

# %%
df.drop('Region',inplace= True,axis=1)

# %%
df
# Out:
#      OrderDate         City  Category         Product  Quantity  UnitPrice  \
# 0   2020-01-01       Boston      Bars          Carrot        33       1.77
# 1   2020-01-04       Boston  Crackers     Whole Wheat        87       3.49
# 2   2020-01-07  Los Angeles   Cookies  Chocolate Chip        58       1.87
# 3   2020-01-10     New York   Cookies  Chocolate Chip        82       1.87
# 4   2020-01-13       Boston   Cookies       Arrowroot        38       2.18
# ..         ...          ...       ...             ...       ...        ...
# 239 2021-12-18       Boston   Cookies       Arrowroot        34       2.18
# 240 2021-12-21       Boston   Cookies  Chocolate Chip       245       1.87
# 241 2021-12-24       Boston  Crackers     Whole Wheat        30       3.49
# 242 2021-12-27  Los Angeles      Bars            Bran        30       1.87
# 243 2021-12-30  Los Angeles   Cookies  Oatmeal Raisin        44       2.84
#
#      TotalPrice
# 0         58.41
# 1        303.63
# ...

# %%
df["OrderDate"]=pd.to_datetime(df["OrderDate"])

# %%
df
# Out:
#      OrderDate         City  Category         Product  Quantity  UnitPrice  \
# 0   2020-01-01       Boston      Bars          Carrot        33       1.77
# 1   2020-01-04       Boston  Crackers     Whole Wheat        87       3.49
# 2   2020-01-07  Los Angeles   Cookies  Chocolate Chip        58       1.87
# 3   2020-01-10     New York   Cookies  Chocolate Chip        82       1.87
# 4   2020-01-13       Boston   Cookies       Arrowroot        38       2.18
# ..         ...          ...       ...             ...       ...        ...
# 239 2021-12-18       Boston   Cookies       Arrowroot        34       2.18
# 240 2021-12-21       Boston   Cookies  Chocolate Chip       245       1.87
# 241 2021-12-24       Boston  Crackers     Whole Wheat        30       3.49
# 242 2021-12-27  Los Angeles      Bars            Bran        30       1.87
# 243 2021-12-30  Los Angeles   Cookies  Oatmeal Raisin        44       2.84
#
#      TotalPrice
# 0         58.41
# 1        303.63
# ...

# %%
print(df.to_string())
# Out:
#      OrderDate         City  Category         Product  Quantity  UnitPrice  TotalPrice
# 0   2020-01-01       Boston      Bars          Carrot        33       1.77       58.41
# 1   2020-01-04       Boston  Crackers     Whole Wheat        87       3.49      303.63
# 2   2020-01-07  Los Angeles   Cookies  Chocolate Chip        58       1.87      108.46
# 3   2020-01-10     New York   Cookies  Chocolate Chip        82       1.87      153.34
# 4   2020-01-13       Boston   Cookies       Arrowroot        38       2.18       82.84
# 5   2020-01-16       Boston      Bars          Carrot        54       1.77       95.58
# 6   2020-01-19       Boston  Crackers     Whole Wheat       149       3.49      520.01
# 7   2020-01-22  Los Angeles      Bars          Carrot        51       1.77       90.27
# 8   2020-01-25     New York      Bars          Carrot       100       1.77      177.00
# 9   2020-01-28     New York    Snacks    Potato Chips        28       1.35       37.80
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   244 non-null    datetime64[ns]
#  1   City        244 non-null    object
#  2   Category    244 non-null    object
#  3   Product     244 non-null    object
#  4   Quantity    244 non-null    int64
#  5   UnitPrice   244 non-null    float64
#  6   TotalPrice  244 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 13.5+ KB

# %%
df.describe()
# Out:
#          Quantity   UnitPrice  TotalPrice
# count  244.000000  244.000000  244.000000
# mean    63.286885    2.200820  136.580246
# std     47.112505    0.600169  108.354231
# min     20.000000    1.350000   33.600000
# 25%     31.000000    1.770000   72.570000
# 50%     47.000000    1.870000  102.755000
# 75%     80.000000    2.840000  159.300000
# max    306.000000    3.490000  817.920000

# %%
df.head()
# Out:
#    OrderDate         City  Category         Product  Quantity  UnitPrice  \
# 0 2020-01-01       Boston      Bars          Carrot        33       1.77
# 1 2020-01-04       Boston  Crackers     Whole Wheat        87       3.49
# 2 2020-01-07  Los Angeles   Cookies  Chocolate Chip        58       1.87
# 3 2020-01-10     New York   Cookies  Chocolate Chip        82       1.87
# 4 2020-01-13       Boston   Cookies       Arrowroot        38       2.18
#
#    TotalPrice
# 0       58.41
# 1      303.63
# 2      108.46
# 3      153.34
# 4       82.84

# %%
df.corr()
# Out:
#             Quantity  UnitPrice  TotalPrice
# Quantity    1.000000  -0.095981    0.936438
# UnitPrice  -0.095981   1.000000    0.181703
# TotalPrice  0.936438   0.181703    1.000000

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
import matplotlib.pyplot as plt

# %%
df.plot()
plt.show()

# %%
df.plot(kind='scatter',x = 'Quantity',y = 'TotalPrice')
plt.show()

# %%
df["TotalPrice"].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["UnitPrice"].plot(kind = 'bar')
# Out:
# <AxesSubplot:>
